# %% [markdown]
# # 04 Perspective transformation tool demo
# This notebook is a placeholder for the new interactive perspective transformation tool. The full quantitative evaluation is handled in a separate publication; here it is included as part of the software framework.

# %%
# Suggested workflow:
# 1. Load one representative frame from a traffic video.
# 2. Select corresponding points on the camera image and map/top-view image.
# 3. Estimate the perspective transform / homography matrix.
# 4. Transform trajectory points and visualize the result.
print('Perspective tool workflow placeholder')
