# %% [markdown]
# # 01 Load dataset
# Load the Traffic Node Video Dataset 2.0 manifest and inspect the available sample files.

# %%
import pandas as pd
manifest = pd.read_csv('../sample_data/dataset_manifest_sample.csv')
manifest

# %%
print('Scenes:', manifest['scene_id'].nunique())
print('Videos:', manifest['video_id'].nunique())
